# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.subplot(2, 1, 1)
plt.subplot(2, 1, 2)
plt.show()

# %%
plt.subplot(2, 2, 1)
plt.subplot(2, 2, 2)
plt.subplot(2, 2, 3)
plt.subplot(2, 2, 4)
plt.show()

# %%
plt.subplot(2, 2, 1)
plt.subplot(2, 2, 2)
plt.subplot(2, 1, 2)

plt.show()

# %%
plt.subplot(2, 2, 1)
x = np.random.random(10)
u = np.random.random(10)
plt.scatter(x,u)

plt.subplot(2, 2, 2)
x = np.arange(8)
y = x**2
plt.plot(x,y)
plt.subplot(2, 1, 2)

plt.show()
